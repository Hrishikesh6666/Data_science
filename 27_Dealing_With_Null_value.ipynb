# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrishikesh6666/Data_science/blob/main/27_Dealing_With_Null_value.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Data.csv',header= None)

# %%
df
# Out:
#           0     1     2     3     4
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 6     Manoj   NaN  66.0  88.0  56.0
# 7     Suraj  55.0   NaN  76.0  87.0
# 8     Sumit  66.0  77.0   NaN  89.0
# 9    Ratish  66.0  55.0  66.0   NaN
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11      NaN  98.0  89.0  98.0  88.0
# 12      NaN  22.0  23.0  34.0  32.0

# %% [markdown]
# # **Remove rows where null value is present**

# %%
df.dropna()
# Out:
#           0     1     2     3     4
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 10  Tanisha  77.0  66.0  56.0  87.0

# %%
df.describe()
# Out:
#                1          2          3          4
# count  12.000000  12.000000  12.000000  12.000000
# mean   64.750000  61.750000  64.500000  72.500000
# std    19.334966  17.602298  25.952754  20.142673
# min    22.000000  23.000000   6.000000  32.000000
# 25%    62.500000  52.500000  53.250000  55.750000
# 50%    65.000000  66.000000  71.000000  82.500000
# 75%    68.750000  69.500000  79.500000  88.000000
# max    98.000000  89.000000  98.000000  89.000000

# %% [markdown]
# # **Filling Some Value in place of Null Value**

# %%
df = pd.read_csv('/content/Data.csv',header= None)

# %%
df[0]=df[0].fillna('Krishna')
df[1]=df[1].fillna('64')
df[2]=df[2].fillna('62')
df[3]=df[3].fillna('65')
df[4]=df[4].fillna('72')

# %%
df
# Out:
#           0     1     2     3     4
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 6     Manoj    64  66.0  88.0  56.0
# 7     Suraj  55.0    62  76.0  87.0
# 8     Sumit  66.0  77.0    65  89.0
# 9    Ratish  66.0  55.0  66.0    72
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11  Krishna  98.0  89.0  98.0  88.0
# 12  Krishna  22.0  23.0  34.0  32.0

# %% [markdown]
# # **IMPUTER**

# %%
# !pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('/content/Data.csv',header= None)

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='mean') # Use np.nan to represent missing values

# %%
df.shape
# Out:
# (13, 5)

# %%
eng = np.reshape(df[1].values, (13,5)) # Use parentheses for np.reshape and remove parentheses after .values
imputer = SimpleImputer(missing_values=np.nan,strategy='most_frequent')
df[1] = imputer.fit_transform(eng)
df['eng'] = imputer.fit_transform(df[['eng']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-26932c53b433> in <cell line: 1>()
# ----> 1 eng = np.reshape(df[1].values, (13,5)) # Use parentheses for np.reshape and remove parentheses after .values
#       2 imputer = SimpleImputer(missing_values=np.nan,strategy='most_frequent')
#       3 df[1] = imputer.fit_transform(eng)
#       4 df['eng'] = imputer.fit_transform(df[['eng']])
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#     286
#     287
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      57
#      58     try:
# ---> 59         return bound(*args, **kwds)
#      60     except TypeError:
# ...
