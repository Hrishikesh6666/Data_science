# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrishikesh6666/Data_science/blob/main/DATA_ANALYSIS_(PANDAS_Library).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Data.csv', header = None)

# %%
df
# Out:
#           0     1     2     3     4
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 6     Manoj   NaN  66.0  88.0  56.0
# 7     Suraj  55.0   NaN  76.0  87.0
# 8     Sumit  66.0  77.0   NaN  89.0
# 9    Ratish  66.0  55.0  66.0   NaN
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11      NaN  98.0  89.0  98.0  88.0
# 12      NaN  22.0  23.0  34.0  32.0

# %%
df.head()
# Out:
#         0     1     2     3     4
# 0  Ashish  45.0  65.0  76.0  78.0
# 1     Raj  65.0  45.0  65.0  76.0
# 2  Rohini  65.0  67.0   6.0  55.0
# 3  Rakesh  65.0  66.0  77.0  88.0
# 4  Rajesh  88.0  77.0  87.0  89.0

# %%
df.tail()
# Out:
#           0     1     2     3     4
# 8     Sumit  66.0  77.0   NaN  89.0
# 9    Ratish  66.0  55.0  66.0   NaN
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11      NaN  98.0  89.0  98.0  88.0
# 12      NaN  22.0  23.0  34.0  32.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       11 non-null     object
#  1   1       12 non-null     float64
#  2   2       12 non-null     float64
#  3   3       12 non-null     float64
#  4   4       12 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 648.0+ bytes

# %%
df.describe()
# this function you can get Mean ,avrage, max min
# Out:
#                1          2          3          4
# count  12.000000  12.000000  12.000000  12.000000
# mean   64.750000  61.750000  64.500000  72.500000
# std    19.334966  17.602298  25.952754  20.142673
# min    22.000000  23.000000   6.000000  32.000000
# 25%    62.500000  52.500000  53.250000  55.750000
# 50%    65.000000  66.000000  71.000000  82.500000
# 75%    68.750000  69.500000  79.500000  88.000000
# max    98.000000  89.000000  98.000000  89.000000

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# 0    2
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64

# %%
df.isna().sum()
# Out:
# 0    2
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64

# %% [markdown]
# # Checking A Dataframe

# %%
df = pd.read_csv('Data.csv', header = None)

name = df[0]
eng = df[1]
hin = df[2]
mth = df[3]
sci = df[4]

del df[0]
del df[1]
del df[2]
del df[3]
del df[4]

# %%
df['name'] = name
df['eng'] = eng
df['hin'] = hin
df['mth'] = mth
df['sci'] = sci

# %%
df
# Out:
#        name   eng   hin   mth   sci
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 6     Manoj   NaN  66.0  88.0  56.0
# 7     Suraj  55.0   NaN  76.0  87.0
# 8     Sumit  66.0  77.0   NaN  89.0
# 9    Ratish  66.0  55.0  66.0   NaN
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11      NaN  98.0  89.0  98.0  88.0
# 12      NaN  22.0  23.0  34.0  32.0

# %% [markdown]
# # Deleate A Perticular Columne

# %%
del df['hin']

# %%
df
# Out:
#        name   eng   mth   sci
# 0    Ashish  45.0  76.0  78.0
# 1       Raj  65.0  65.0  76.0
# 2    Rohini  65.0   6.0  55.0
# 3    Rakesh  65.0  77.0  88.0
# 4    Rajesh  88.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0
# 6     Manoj   NaN  88.0  56.0
# 7     Suraj  55.0  76.0  87.0
# 8     Sumit  66.0   NaN  89.0
# 9    Ratish  66.0  66.0   NaN
# 10  Tanisha  77.0  56.0  87.0
# 11      NaN  98.0  98.0  88.0
# 12      NaN  22.0  34.0  32.0

# %% [markdown]
# # SLICING THE DATA IN DATASET

# %%
# FOR SLICING THE DATA WE CAN USE df.iloc[:,:] function first for ROW and second  for COLUMN

# %%
df = pd.read_csv('/content/Data.csv',header = None)

# %%
df.iloc[0:5,0:3]
# Out:
#         0     1     2
# 0  Ashish  45.0  65.0
# 1     Raj  65.0  45.0
# 2  Rohini  65.0  67.0
# 3  Rakesh  65.0  66.0
# 4  Rajesh  88.0  77.0

# %% [markdown]
# ## SHAPE OF DATASET

# %%
df.shape
# Out:
# (13, 5)

# %%
df.size #Total size of Data
# Out:
# 65

# %% [markdown]
# # TO TAKE RANDOM SAMPLES FROM DATA SET YOU USE

# %%
df.sample()
# Out:
#        0     1   2     3     4
# 7  Suraj  55.0 NaN  76.0  87.0

# %% [markdown]
# # FIND UNIQUE VALUES IN PERTICULAR ROW AND COLUMN

# %%
df[df[0].isin(sci)]
# Out:
#       0     1     2     3     4
# 11  NaN  98.0  89.0  98.0  88.0
# 12  NaN  22.0  23.0  34.0  32.0

# %% [markdown]
# # **FILLING NULL VALUE**
#
# > Add blockquote

# %%
'''TO FILL THE NULL VALUE YOU CAN TAKE (AVERAGE, MEDIAN, MODE) ALSO
BUT YOU WORKING ON NAME THERE IS NOT AVERAGE VALUE IN THAT CASE YOU CAN USE GIVEN CODE'''

# %%
df['name']= df['name'].fillna('KRISHNA')

# %%
df
# Out:
#        name   eng   hin   mth   sci
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 6     Manoj   NaN  66.0  88.0  56.0
# 7     Suraj  55.0   NaN  76.0  87.0
# 8     Sumit  66.0  77.0   NaN  89.0
# 9    Ratish  66.0  55.0  66.0   NaN
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11  KRISHNA  98.0  89.0  98.0  88.0
# 12  KRISHNA  22.0  23.0  34.0  32.0

# %% [markdown]
# # REMOVEING ROWS HAVING NULL VALUE

# %%
df.dropna()
# Out:
#        name   eng   hin   mth   sci
# 0    Ashish  45.0  65.0  76.0  78.0
# 1       Raj  65.0  45.0  65.0  76.0
# 2    Rohini  65.0  67.0   6.0  55.0
# 3    Rakesh  65.0  66.0  77.0  88.0
# 4    Rajesh  88.0  77.0  87.0  89.0
# 5    Manish  65.0  45.0  45.0  45.0
# 10  Tanisha  77.0  66.0  56.0  87.0
# 11  KRISHNA  98.0  89.0  98.0  88.0
# 12  KRISHNA  22.0  23.0  34.0  32.0

# %%
df.dropna().isnull().sum()
# Out:
# name    0
# eng     0
# hin     0
# mth     0
# sci     0
# dtype: int64

# %%
df.describe()
# Out:
#              eng        hin        mth        sci
# count  13.000000  12.000000  12.000000  12.000000
# mean   64.750000  61.750000  64.500000  72.500000
# std    18.511821  17.602298  25.952754  20.142673
# min    22.000000  23.000000   6.000000  32.000000
# 25%    64.750000  52.500000  53.250000  55.750000
# 50%    65.000000  66.000000  71.000000  82.500000
# 75%    66.000000  69.500000  79.500000  88.000000
# max    98.000000  89.000000  98.000000  89.000000

# %%
df['eng'] = df['eng'].fillna(df['eng'].mean())

# %%
df['hin'] = df['hin'].fillna(df['hin'].max())

# %%
df
# Out:
#        name    eng   hin   mth   sci
# 0    Ashish  45.00  65.0  76.0  78.0
# 1       Raj  65.00  45.0  65.0  76.0
# 2    Rohini  65.00  67.0   6.0  55.0
# 3    Rakesh  65.00  66.0  77.0  88.0
# 4    Rajesh  88.00  77.0  87.0  89.0
# 5    Manish  65.00  45.0  45.0  45.0
# 6     Manoj  64.75  66.0  88.0  56.0
# 7     Suraj  55.00  89.0  76.0  87.0
# 8     Sumit  66.00  77.0   NaN  89.0
# 9    Ratish  66.00  55.0  66.0   NaN
# 10  Tanisha  77.00  66.0  56.0  87.0
# 11  KRISHNA  98.00  89.0  98.0  88.0
# 12  KRISHNA  22.00  23.0  34.0  32.0
