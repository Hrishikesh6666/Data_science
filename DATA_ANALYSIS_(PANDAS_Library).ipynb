# %% [markdown]
# <a href="https://colab.research.google.com/github/Hrishikesh6666/Data_science/blob/main/DATA_ANALYSIS_(PANDAS_Library).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Data.csv')

# %%
df
# Out:
#      Ashish    45    65    76    78
# 0       Raj  65.0  45.0  65.0  76.0
# 1    Rohini  65.0  67.0   6.0  55.0
# 2    Rakesh  65.0  66.0  77.0  88.0
# 3    Rajesh  88.0  77.0  87.0  89.0
# 4    Manish  65.0  45.0  45.0  45.0
# 5     Manoj   NaN  66.0  88.0  56.0
# 6     Suraj  55.0   NaN  76.0  87.0
# 7     Sumit  66.0  77.0   NaN  89.0
# 8    Ratish  66.0  55.0  66.0   NaN
# 9   Tanisha  77.0  66.0  56.0  87.0
# 10      NaN  98.0  89.0  98.0  88.0
# 11      NaN  22.0  23.0  34.0  32.0

# %%
df.head()
# Out:
#    Ashish    45    65    76    78
# 0     Raj  65.0  45.0  65.0  76.0
# 1  Rohini  65.0  67.0   6.0  55.0
# 2  Rakesh  65.0  66.0  77.0  88.0
# 3  Rajesh  88.0  77.0  87.0  89.0
# 4  Manish  65.0  45.0  45.0  45.0

# %%
df.tail()
# Out:
#      Ashish    45    65    76    78
# 7     Sumit  66.0  77.0   NaN  89.0
# 8    Ratish  66.0  55.0  66.0   NaN
# 9   Tanisha  77.0  66.0  56.0  87.0
# 10      NaN  98.0  89.0  98.0  88.0
# 11      NaN  22.0  23.0  34.0  32.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ashish  10 non-null     object
#  1   45      11 non-null     float64
#  2   65      11 non-null     float64
#  3   76      11 non-null     float64
#  4   78      11 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 608.0+ bytes

# %%
df.describe()
# this function you can get Mean ,avrage, max min
# Out:
#               45         65         76         78
# count  11.000000  11.000000  11.000000  11.000000
# mean   66.545455  61.454545  63.454545  72.000000
# std    19.200852  18.430212  26.953158  21.047565
# min    22.000000  23.000000   6.000000  32.000000
# 25%    65.000000  50.000000  50.500000  55.500000
# 50%    65.000000  66.000000  66.000000  87.000000
# 75%    71.500000  72.000000  82.000000  88.000000
# max    98.000000  89.000000  98.000000  89.000000

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Ashish    2
# 45        1
# 65        1
# 76        1
# 78        1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Ashish    2
# 45        1
# 65        1
# 76        1
# 78        1
# dtype: int64

# %% [markdown]
# # Checking A Dataframe
